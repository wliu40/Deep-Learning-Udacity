# %% [markdown]
# # Anna KaRNNa
#
# In this notebook, I'll build a character-wise RNN trained on Anna Karenina, one of my all-time favorite books. It'll be able to generate new text based on the text from the book.
#
# This network is based off of Andrej Karpathy's [post on RNNs](http://karpathy.github.io/2015/05/21/rnn-effectiveness/) and [implementation in Torch](https://github.com/karpathy/char-rnn). Also, some information [here at r2rt](http://r2rt.com/recurrent-neural-networks-in-tensorflow-ii.html) and from [Sherjil Ozair](https://github.com/sherjilozair/char-rnn-tensorflow) on GitHub. Below is the general architecture of the character-wise RNN.
#
# <img src="assets/charseq.jpeg" width="500">

# %%
import time
from collections import namedtuple

import numpy as np
import tensorflow as tf

# %% [markdown]
# First we'll load the text file and convert it into integers for our network to use. Here I'm creating a couple dictionaries to convert the characters to and from integers. Encoding the characters as integers makes it easier to use as input in the network.

# %%
with open('anna.txt', 'r') as f:
    text=f.read()
vocab = set(text)
vocab_to_int = {c: i for i, c in enumerate(vocab)}
int_to_vocab = dict(enumerate(vocab))
encoded = np.array([vocab_to_int[c] for c in text], dtype=np.int32)

# %% [markdown]
# Let's check out the first 100 characters, make sure everything is peachy. According to the [American Book Review](http://americanbookreview.org/100bestlines.asp), this is the 6th best first line of a book ever.

# %%
text[:100]
# Out:
# 'Chapter 1\n\n\nHappy families are all alike; every unhappy family is unhappy in its own\nway.\n\nEverythin'

# %% [markdown]
# And we can see the characters encoded as integers.

# %%
encoded[:100]
# Out:
# array([53, 23, 49, 81, 22, 26, 37, 16, 27, 45, 45, 45, 32, 49, 81, 81, 24,
#        16, 17, 49, 60, 77, 73, 77, 26,  4, 16, 49, 37, 26, 16, 49, 73, 73,
#        16, 49, 73, 77, 72, 26, 58, 16, 26, 40, 26, 37, 24, 16, 69, 70, 23,
#        49, 81, 81, 24, 16, 17, 49, 60, 77, 73, 24, 16, 77,  4, 16, 69, 70,
#        23, 49, 81, 81, 24, 16, 77, 70, 16, 77, 22,  4, 16, 21, 30, 70, 45,
#        30, 49, 24, 42, 45, 45,  9, 40, 26, 37, 24, 22, 23, 77, 70])

# %% [markdown]
# Since the network is working with individual characters, it's similar to a classification problem in which we are trying to predict the next character from the previous text.  Here's how many 'classes' our network has to pick from.

# %%
len(vocab)
# Out:
# 83

# %% [markdown]
# ## Making training mini-batches
#
# Here is where we'll make our mini-batches for training. Remember that we want our batches to be multiple sequences of some desired number of sequence steps. Considering a simple example, our batches would look like this:
#
# <img src="assets/sequence_batching@1x.png" width=500px>
#
#
# <br>
# We have our text encoded as integers as one long array in `encoded`. Let's create a function that will give us an iterator for our batches. I like using [generator functions](https://jeffknupp.com/blog/2013/04/07/improve-your-python-yield-and-generators-explained/) to do this. Then we can pass `encoded` into this function and get our batch generator.
#
# The first thing we need to do is discard some of the text so we only have completely full batches. Each batch contains $N \times M$ characters, where $N$ is the batch size (the number of sequences) and $M$ is the number of steps （上图中，N=2,M=3）. Then, to get the number of batches we can make from some array `arr`, you divide the length of `arr` by the batch size. Once you know the number of batches and the batch size, you can get the total number of characters to keep.
#
# After that, we need to split `arr` into $N$ sequences. You can do this using `arr.reshape(size)` where `size` is a tuple containing the dimensions sizes of the reshaped array. We know we want $N$ sequences (`n_seqs` below), let's make that the size of the first dimension. For the second dimension, you can use `-1` as a placeholder in the size, it'll fill up the array with the appropriate data for you. After this, you should have an array that is $N \times (M * K)$ where $K$ is the number of batches.
#
# Now that we have this array, we can iterate through it to get our batches. The idea is each batch is a $N \times M$ window on the array. For each subsequent batch, the window moves over by `n_steps`. We also want to create both the input and target arrays. Remember that the targets are the inputs shifted over one character. You'll usually see the first input character used as the last target character, so something like this:
# ```python
# y[:, :-1], y[:, -1] = x[:, 1:], x[:, 0]
# ```
# where `x` is the input batch and `y` is the target batch.
#
# The way I like to do this window is use `range` to take steps of size `n_steps` from $0$ to `arr.shape[1]`, the total number of steps in each sequence. That way, the integers you get from `range` always point to the start of a batch, and each window is `n_steps` wide.

# %%
import numpy as np
x = [[1,2,3],[4,5,6],[7,8,9]]
x = np.array(x)
print(x)
y = np.zeros_like(x)
y[:, :-1], y[:, -1] = x[:, 1:], x[:, 0]
print()
print(y)
# Out:
# [[1 2 3]
#  [4 5 6]
#  [7 8 9]]
#
# [[2 3 1]
#  [5 6 4]
#  [8 9 7]]

# %%
def get_batches(arr, n_seqs, n_steps):
    '''Create a generator that returns batches of size
       n_seqs x n_steps from arr.
       
       Arguments
       ---------
       arr: Array you want to make batches from
       n_seqs: Batch size, the number of sequences per batch
       n_steps: Number of sequence steps per batch
    '''
    # Get the number of characters per batch and number of batches we can make
    characters_per_batch = n_seqs * n_steps
    n_batches = len(arr)//characters_per_batch
    
    # Keep only enough characters to make full batches
    arr = arr[:n_batches * characters_per_batch]
    
    # Reshape into n_seqs rows
    arr = arr.reshape((n_seqs, -1))
    
    for n in range(0, arr.shape[1], n_steps):
        # The features
        x = arr[:, n:n+n_steps]
        # The targets, shifted by one
        y = np.zeros_like(x)
        y[:, :-1], y[:, -1] = x[:, 1:], x[:, 0]
        yield x, y

# %% [markdown]
# Now I'll make my data sets and we can check out what's going on here. Here I'm going to use a batch size of 10 and 50 sequence steps.

# %%
batches = get_batches(encoded, 10, 50)
x, y = next(batches)

# %%
print('x\n', x[:10, :10])
print('\ny\n', y[:10, :10])
# Out:
# x
#  [[53 23 49 81 22 26 37 16 27 45]
#  [16 49 60 16 70 21 22 16 28 21]
#  [40 77 70 42 45 45 56 48 26  4]
#  [70 16 63 69 37 77 70 28 16 23]
#  [16 77 22 16 77  4 36 16  4 77]
#  [16 55 22 16 30 49  4 45 21 70]
#  [23 26 70 16 71 21 60 26 16 17]
#  [58 16 18 69 22 16 70 21 30 16]
#  [22 16 77  4 70 47 22 42 16 51]
#  [16  4 49 77 63 16 22 21 16 23]]
#
# y
#  [[23 49 81 22 26 37 16 27 45 45]
#  [49 60 16 70 21 22 16 28 21 77]
#  [77 70 42 45 45 56 48 26  4 36]
#  [16 63 69 37 77 70 28 16 23 77]
#  [77 22 16 77  4 36 16  4 77 37]
#  [55 22 16 30 49  4 45 21 70 73]
#  [26 70 16 71 21 60 26 16 17 21]
#  [16 18 69 22 16 70 21 30 16  4]
#  [16 77  4 70 47 22 42 16 51 23]
#  [ 4 49 77 63 16 22 21 16 23 26]]

# %% [markdown]
# If you implemented `get_batches` correctly, the above output should look something like
# ```
# x
#  [[55 63 69 22  6 76 45  5 16 35]
#  [ 5 69  1  5 12 52  6  5 56 52]
#  [48 29 12 61 35 35  8 64 76 78]
#  [12  5 24 39 45 29 12 56  5 63]
#  [ 5 29  6  5 29 78 28  5 78 29]
#  [ 5 13  6  5 36 69 78 35 52 12]
#  [63 76 12  5 18 52  1 76  5 58]
#  [34  5 73 39  6  5 12 52 36  5]
#  [ 6  5 29 78 12 79  6 61  5 59]
#  [ 5 78 69 29 24  5  6 52  5 63]]
#
# y
#  [[63 69 22  6 76 45  5 16 35 35]
#  [69  1  5 12 52  6  5 56 52 29]
#  [29 12 61 35 35  8 64 76 78 28]
#  [ 5 24 39 45 29 12 56  5 63 29]
#  [29  6  5 29 78 28  5 78 29 45]
#  [13  6  5 36 69 78 35 52 12 43]
#  [76 12  5 18 52  1 76  5 58 52]
#  [ 5 73 39  6  5 12 52 36  5 78]
#  [ 5 29 78 12 79  6 61  5 59 63]
#  [78 69 29 24  5  6 52  5 63 76]]
#  ```
#  although the exact numbers will be different. Check to make sure the data is shifted over one step for `y`.

# %% [markdown]
# ## Building the model
#
# Below is where you'll build the network. We'll break it up into parts so it's easier to reason about each bit. Then we can connect them up into the whole network.
#
# <img src="assets/charRNN.png" width=500px>
#
#
# ### Inputs
#
# First off we'll create our input placeholders. As usual we need placeholders for the training data and the targets. We'll also create a placeholder for dropout layers called `keep_prob`.

# %%
def build_inputs(batch_size, num_steps):
    ''' Define placeholders for inputs, targets, and dropout 
    
        Arguments
        ---------
        batch_size: Batch size, number of sequences per batch
        num_steps: Number of sequence steps in a batch
        
    '''
    # Declare placeholders we'll feed into the graph
    inputs = tf.placeholder(tf.int32, [batch_size, num_steps], name='inputs')
    targets = tf.placeholder(tf.int32, [batch_size, num_steps], name='targets')
    
    # Keep probability placeholder for drop out layers
    keep_prob = tf.placeholder(tf.float32, name='keep_prob')
    
    return inputs, targets, keep_prob

# %% [markdown]
# ### LSTM Cell
#
# Here we will create the LSTM cell we'll use in the hidden layer. We'll use this cell as a building block for the RNN. So we aren't actually defining the RNN here, just the type of cell we'll use in the hidden layer.
#
# We first create a basic LSTM cell with
#
# ```python
# lstm = tf.contrib.rnn.BasicLSTMCell(num_units)
# ```
#
# where `num_units` is the number of units in the hidden layers in the cell. Then we can add dropout by wrapping it with
#
# ```python
# tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=keep_prob)
# ```
# You pass in a cell and it will automatically add dropout to the inputs or outputs. Finally, we can stack up the LSTM cells into layers with [`tf.contrib.rnn.MultiRNNCell`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/rnn/MultiRNNCell). With this, you pass in a list of cells and it will send the output of one cell into the next cell. Previously with TensorFlow 1.0, you could do this
#
# ```python
# tf.contrib.rnn.MultiRNNCell([cell]*num_layers)
# ```
#
# This might look a little weird if you know Python well because this will create a list of the same `cell` object. However, TensorFlow 1.0 will create different weight matrices for all `cell` objects. But, starting with TensorFlow 1.1 you actually need to create new cell objects in the list. To get it to work in TensorFlow 1.1, it should look like
#
# ```python
# def build_cell(num_units, keep_prob):
#     lstm = tf.contrib.rnn.BasicLSTMCell(num_units)
#     drop = tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=keep_prob)
#
#     return drop
#
# tf.contrib.rnn.MultiRNNCell([build_cell(num_units, keep_prob) for _ in range(num_layers)])
# ```
#
# Even though this is actually multiple LSTM cells stacked on each other, you can treat the multiple layers as one cell.
#
# We also need to create an initial cell state of all zeros. This can be done like so
#
# ```python
# initial_state = cell.zero_state(batch_size, tf.float32)
# ```
#
# Below, we implement the `build_lstm` function to create these LSTM cells and the initial state.

# %%
def build_lstm(lstm_size, num_layers, batch_size, keep_prob):
    ''' Build LSTM cell.
    
        Arguments
        ---------
        keep_prob: Scalar tensor (tf.placeholder) for the dropout keep probability
        lstm_size: Size of the hidden layers in the LSTM cells
        num_layers: Number of LSTM layers
        batch_size: Batch size

    '''
    ### Build the LSTM Cell
    
    def build_cell(lstm_size, keep_prob):
        # Use a basic LSTM cell
        lstm = tf.contrib.rnn.BasicLSTMCell(lstm_size)
        
        # Add dropout to the cell
        drop = tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=keep_prob)
        return drop
    
    
    # Stack up multiple LSTM layers, for deep learning
    cell = tf.contrib.rnn.MultiRNNCell([build_cell(lstm_size, keep_prob) for _ in range(num_layers)])
    initial_state = cell.zero_state(batch_size, tf.float32)
    
    return cell, initial_state

# %% [markdown]
# ### RNN Output
#
# Here we'll create the output layer. We need to connect the output of the RNN cells to a full connected layer with a softmax output. The softmax output gives us a probability distribution we can use to predict the next character.
#
# If our input has batch size $N$, number of steps $M$, and the hidden layer has $L$ hidden units, then the output is a 3D tensor with size $N \times M \times L$. The output of each LSTM cell has size $L$, we have $M$ of them, one for each sequence step, and we have $N$ sequences. So the total size is $N \times M \times L$.
#
# We are using the same fully connected layer, the same weights, for each of the outputs. Then, to make things easier, we should reshape the outputs into a 2D tensor with shape $(M * N) \times L$. That is, one row for each sequence and step, where the values of each row are the output from the LSTM cells.
#
# One we have the outputs reshaped, we can do the matrix multiplication with the weights. We need to wrap the weight and bias variables in a variable scope with `tf.variable_scope(scope_name)` because there are weights being created in the LSTM cells. TensorFlow will throw an error if the weights created here have the same names as the weights created in the LSTM cells, which they will be default. To avoid this, we wrap the variables in a variable scope so we can give them unique names.

# %%
def build_output(lstm_output, in_size, out_size):
    ''' Build a softmax layer, return the softmax output and logits.
    
        Arguments
        ---------
        
        x: Input tensor
        in_size: Size of the input tensor, for example, size of the LSTM cells
        out_size: Size of this softmax layer
    
    '''

    # Reshape output so it's a bunch of rows, one row for each step for each sequence.
    # That is, the shape should be batch_size*num_steps rows by lstm_size columns
    seq_output = tf.concat(lstm_output, axis=1)
    x = tf.reshape(seq_output, [-1, in_size])
    
    # Connect the RNN outputs to a softmax layer
    with tf.variable_scope('softmax'):
        softmax_w = tf.Variable(tf.truncated_normal((in_size, out_size), stddev=0.1))
        softmax_b = tf.Variable(tf.zeros(out_size))
    
    # Since output is a bunch of rows of RNN cell outputs, logits will be a bunch
    # of rows of logit outputs, one for each step and sequence
    logits = tf.matmul(x, softmax_w) + softmax_b
    
    # Use softmax to get the probabilities for predicted characters
    out = tf.nn.softmax(logits, name='predictions')
    
    return out, logits

# %% [markdown]
# ### Training loss
#
# Next up is the training loss. We get the logits and targets and calculate the softmax cross-entropy loss. First we need to one-hot encode the targets, we're getting them as encoded characters. Then, reshape the one-hot targets so it's a 2D tensor with size $(M*N) \times C$ where $C$ is the number of classes/characters we have. Remember that we reshaped the LSTM outputs and ran them through a fully connected layer with $C$ units. So our logits will also have size $(M*N) \times C$.
#
# Then we run the logits and targets through `tf.nn.softmax_cross_entropy_with_logits` and find the mean to get the loss.

# %%
def build_loss(logits, targets, lstm_size, num_classes):
    ''' Calculate the loss from the logits and the targets.
    
        Arguments
        ---------
        logits: Logits from final fully connected layer
        targets: Targets for supervised learning
        lstm_size: Number of LSTM hidden units
        num_classes: Number of classes in targets
        
    '''
    
    # One-hot encode targets and reshape to match logits, one row per batch_size per step
    y_one_hot = tf.one_hot(targets, num_classes)
    y_reshaped = tf.reshape(y_one_hot, logits.get_shape())
    
    # Softmax cross entropy loss
    loss = tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y_reshaped)
    loss = tf.reduce_mean(loss)
    return loss

# %% [markdown]
# ### Optimizer
#
# Here we build the optimizer. Normal RNNs have have issues gradients exploding and disappearing. LSTMs fix the disappearance problem, but the gradients can still grow without bound. To fix this, we can clip the gradients above some threshold. That is, if a gradient is larger than that threshold, we set it to the threshold. This will ensure the gradients never grow overly large. Then we use an AdamOptimizer for the learning step.

# %%
def build_optimizer(loss, learning_rate, grad_clip):
    ''' Build optmizer for training, using gradient clipping.
    
        Arguments:
        loss: Network loss
        learning_rate: Learning rate for optimizer
    
    '''
    
    # Optimizer for training, using gradient clipping to control exploding gradients
    tvars = tf.trainable_variables()
    grads, _ = tf.clip_by_global_norm(tf.gradients(loss, tvars), grad_clip)
    train_op = tf.train.AdamOptimizer(learning_rate)
    optimizer = train_op.apply_gradients(zip(grads, tvars))
    
    return optimizer

# %% [markdown]
# ### Build the network
#
# Now we can put all the pieces together and build a class for the network. To actually run data through the LSTM cells, we will use [`tf.nn.dynamic_rnn`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/nn/dynamic_rnn). This function will pass the hidden and cell states across LSTM cells appropriately for us. It returns the outputs for each LSTM cell at each step for each sequence in the mini-batch. It also gives us the final LSTM state. We want to save this state as `final_state` so we can pass it to the first LSTM cell in the the next mini-batch run. For `tf.nn.dynamic_rnn`, we pass in the cell and initial state we get from `build_lstm`, as well as our input sequences. Also, we need to one-hot encode the inputs before going into the RNN.

# %%
class CharRNN:
    
    def __init__(self, num_classes, batch_size=64, num_steps=50, 
                       lstm_size=128, num_layers=2, learning_rate=0.001, 
                       grad_clip=5, sampling=False):
    
        # When we're using this network for sampling later, we'll be passing in
        # one character at a time, so providing an option for that
        if sampling == True:
            batch_size, num_steps = 1, 1
        else:
            batch_size, num_steps = batch_size, num_steps

        tf.reset_default_graph()
        
        # Build the input placeholder tensors
        self.inputs, self.targets, self.keep_prob = build_inputs(batch_size, num_steps)

        # Build the LSTM cell
        cell, self.initial_state = build_lstm(lstm_size, num_layers, batch_size, self.keep_prob)

        ### Run the data through the RNN layers
        # First, one-hot encode the input tokens
        x_one_hot = tf.one_hot(self.inputs, num_classes)
        
        # Run each sequence step through the RNN and collect the outputs
        outputs, state = tf.nn.dynamic_rnn(cell, x_one_hot, initial_state=self.initial_state)
        self.final_state = state
        
        # Get softmax predictions and logits
        self.prediction, self.logits = build_output(outputs, lstm_size, num_classes)
        
        # Loss and optimizer (with gradient clipping)
        self.loss = build_loss(self.logits, self.targets, lstm_size, num_classes)
        self.optimizer = build_optimizer(self.loss, learning_rate, grad_clip)

# %% [markdown]
# ## Hyperparameters
#
# Here I'm defining the hyperparameters for the network.
#
# * `batch_size` - Number of sequences running through the network in one pass.
# * `num_steps` - Number of characters in the sequence the network is trained on. Larger is better typically, the network will learn more long range dependencies. But it takes longer to train. 100 is typically a good number here.
# * `lstm_size` - The number of units in the hidden layers.
# * `num_layers` - Number of hidden LSTM layers to use
# * `learning_rate` - Learning rate for training
# * `keep_prob` - The dropout keep probability when training. If you're network is overfitting, try decreasing this.
#
# Here's some good advice from Andrej Karpathy on training the network. I'm going to copy it in here for your benefit, but also link to [where it originally came from](https://github.com/karpathy/char-rnn#tips-and-tricks).
#
# > ## Tips and Tricks
#
# >### Monitoring Validation Loss vs. Training Loss
# >If you're somewhat new to Machine Learning or Neural Networks it can take a bit of expertise to get good models. The most important quantity to keep track of is the difference between your training loss (printed during training) and the validation loss (printed once in a while when the RNN is run on the validation data (by default every 1000 iterations)). In particular:
#
# > - If your training loss is much lower than validation loss then this means the network might be **overfitting**. Solutions to this are to decrease your network size, or to increase dropout. For example you could try dropout of 0.5 and so on.
# > - If your training/validation loss are about equal then your model is **underfitting**. Increase the size of your model (either number of layers or the raw number of neurons per layer)
#
# > ### Approximate number of parameters
#
# > The two most important parameters that control the model are `lstm_size` and `num_layers`. I would advise that you always use `num_layers` of either 2/3. The `lstm_size` can be adjusted based on how much data you have. The two important quantities to keep track of here are:
#
# > - The number of parameters in your model. This is printed when you start training.
# > - The size of your dataset. 1MB file is approximately 1 million characters.
#
# >These two should be about the same order of magnitude. It's a little tricky to tell. Here are some examples:
#
# > - I have a 100MB dataset and I'm using the default parameter settings (which currently print 150K parameters). My data size is significantly larger (100 mil >> 0.15 mil), so I expect to heavily underfit. I am thinking I can comfortably afford to make `lstm_size` larger.
# > - I have a 10MB dataset and running a 10 million parameter model. I'm slightly nervous and I'm carefully monitoring my validation loss. If it's larger than my training loss then I may want to try to increase dropout a bit and see if that helps the validation loss.
#
# > ### Best models strategy
#
# >The winning strategy to obtaining very good models (if you have the compute time) is to always err on making the network larger (as large as you're willing to wait for it to compute) and then try different dropout values (between 0,1). Whatever model has the best validation performance (the loss, written in the checkpoint filename, low is good) is the one you should use in the end.
#
# >It is very common in deep learning to run many different models with many different hyperparameter settings, and in the end take whatever checkpoint gave the best validation performance.
#
# >By the way, the size of your training and validation splits are also parameters. Make sure you have a decent amount of data in your validation set or otherwise the validation performance will be noisy and not very informative.

# %%
batch_size = 100        # Sequences per batch
num_steps = 100         # Number of sequence steps per batch
lstm_size = 512         # Size of hidden layers in LSTMs
num_layers = 2          # Number of LSTM layers
learning_rate = 0.001   # Learning rate
keep_prob = 0.5         # Dropout keep probability

# %% [markdown]
# ## Time for training
#
# This is typical training code, passing inputs and targets into the network, then running the optimizer. Here we also get back the final LSTM state for the mini-batch. Then, we pass that state back into the network so the next batch can continue the state from the previous batch. And every so often (set by `save_every_n`) I save a checkpoint.
#
# Here I'm saving checkpoints with the format
#
# `i{iteration number}_l{# hidden layer units}.ckpt`

# %%
epochs = 20
# Save every N iterations
save_every_n = 200

model = CharRNN(len(vocab), batch_size=batch_size, num_steps=num_steps,
                lstm_size=lstm_size, num_layers=num_layers, 
                learning_rate=learning_rate)

saver = tf.train.Saver(max_to_keep=100)
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    # Use the line below to load a checkpoint and resume training
    #saver.restore(sess, 'checkpoints/______.ckpt')
    counter = 0
    for e in range(epochs):
        # Train network
        new_state = sess.run(model.initial_state)
        loss = 0
        for x, y in get_batches(encoded, batch_size, num_steps):
            counter += 1
            start = time.time()
            feed = {model.inputs: x,
                    model.targets: y,
                    model.keep_prob: keep_prob,
                    model.initial_state: new_state}
            batch_loss, new_state, _ = sess.run([model.loss, 
                                                 model.final_state, 
                                                 model.optimizer], 
                                                 feed_dict=feed)
            
            end = time.time()
            print('Epoch: {}/{}... '.format(e+1, epochs),
                  'Training Step: {}... '.format(counter),
                  'Training loss: {:.4f}... '.format(batch_loss),
                  '{:.4f} sec/batch'.format((end-start)))
        
            if (counter % save_every_n == 0):
                saver.save(sess, "checkpoints/i{}_l{}.ckpt".format(counter, lstm_size))
    
    saver.save(sess, "checkpoints/i{}_l{}.ckpt".format(counter, lstm_size))
# Out:
# Epoch: 1/20...  Training Step: 1...  Training loss: 4.4218...  14.3820 sec/batch
# Epoch: 1/20...  Training Step: 2...  Training loss: 4.3439...  12.1234 sec/batch
# Epoch: 1/20...  Training Step: 3...  Training loss: 3.9256...  11.5915 sec/batch
# Epoch: 1/20...  Training Step: 4...  Training loss: 4.6862...  11.0594 sec/batch
# Epoch: 1/20...  Training Step: 5...  Training loss: 4.1249...  10.5585 sec/batch
# Epoch: 1/20...  Training Step: 6...  Training loss: 3.8102...  10.5140 sec/batch
# Epoch: 1/20...  Training Step: 7...  Training loss: 3.6710...  12.0480 sec/batch
# Epoch: 1/20...  Training Step: 8...  Training loss: 3.5531...  11.4031 sec/batch
# Epoch: 1/20...  Training Step: 9...  Training loss: 3.4750...  9.8161 sec/batch
# Epoch: 1/20...  Training Step: 10...  Training loss: 3.4522...  9.6680 sec/batch
# Epoch: 1/20...  Training Step: 11...  Training loss: 3.4181...  9.4693 sec/batch
# Epoch: 1/20...  Training Step: 12...  Training loss: 3.3872...  11.1900 sec/batch
# Epoch: 1/20...  Training Step: 13...  Training loss: 3.3353...  12.4998 sec/batch
# Epoch: 1/20...  Training Step: 14...  Training loss: 3.3158...  10.7942 sec/batch
# Epoch: 1/20...  Training Step: 15...  Training loss: 3.3184...  11.0919 sec/batch
# Epoch: 1/20...  Training Step: 16...  Training loss: 3.3029...  9.9491 sec/batch
# Epoch: 1/20...  Training Step: 17...  Training loss: 3.2868...  9.9286 sec/batch
# Epoch: 1/20...  Training Step: 18...  Training loss: 3.3124...  9.7350 sec/batch
# Epoch: 1/20...  Training Step: 19...  Training loss: 3.2822...  11.9425 sec/batch
# Epoch: 1/20...  Training Step: 20...  Training loss: 3.2365...  11.0637 sec/batch
# Epoch: 1/20...  Training Step: 21...  Training loss: 3.2551...  11.9721 sec/batch
# Epoch: 1/20...  Training Step: 22...  Training loss: 3.2451...  12.7837 sec/batch
# Epoch: 1/20...  Training Step: 23...  Training loss: 3.2280...  11.6760 sec/batch
# Epoch: 1/20...  Training Step: 24...  Training loss: 3.2393...  10.5081 sec/batch
# Epoch: 1/20...  Training Step: 25...  Training loss: 3.2240...  11.2400 sec/batch
# Epoch: 1/20...  Training Step: 26...  Training loss: 3.2305...  12.2063 sec/batch
# Epoch: 1/20...  Training Step: 27...  Training loss: 3.2336...  10.2990 sec/batch
# Epoch: 1/20...  Training Step: 28...  Training loss: 3.2028...  11.6398 sec/batch
# Epoch: 1/20...  Training Step: 29...  Training loss: 3.2085...  11.7984 sec/batch
# Epoch: 1/20...  Training Step: 30...  Training loss: 3.2154...  10.5340 sec/batch
# Epoch: 1/20...  Training Step: 31...  Training loss: 3.2273...  10.2954 sec/batch
# Epoch: 1/20...  Training Step: 32...  Training loss: 3.1988...  10.2653 sec/batch
# Epoch: 1/20...  Training Step: 33...  Training loss: 3.1818...  10.2564 sec/batch
# Epoch: 1/20...  Training Step: 34...  Training loss: 3.2044...  10.0823 sec/batch
# Epoch: 1/20...  Training Step: 35...  Training loss: 3.1815...  9.9162 sec/batch
# Epoch: 1/20...  Training Step: 36...  Training loss: 3.1986...  9.6505 sec/batch
# Epoch: 1/20...  Training Step: 37...  Training loss: 3.1713...  9.7196 sec/batch
# Epoch: 1/20...  Training Step: 38...  Training loss: 3.1772...  9.8337 sec/batch
# Epoch: 1/20...  Training Step: 39...  Training loss: 3.1680...  9.6665 sec/batch
# Epoch: 1/20...  Training Step: 40...  Training loss: 3.1710...  9.7815 sec/batch
# Epoch: 1/20...  Training Step: 41...  Training loss: 3.1560...  9.6279 sec/batch
# Epoch: 1/20...  Training Step: 42...  Training loss: 3.1578...  9.6750 sec/batch
# Epoch: 1/20...  Training Step: 43...  Training loss: 3.1545...  9.8941 sec/batch
# Epoch: 1/20...  Training Step: 44...  Training loss: 3.1618...  9.8177 sec/batch
# Epoch: 1/20...  Training Step: 45...  Training loss: 3.1471...  9.6975 sec/batch
# Epoch: 1/20...  Training Step: 46...  Training loss: 3.1650...  9.6710 sec/batch
# Epoch: 1/20...  Training Step: 47...  Training loss: 3.1685...  9.6144 sec/batch
# Epoch: 1/20...  Training Step: 48...  Training loss: 3.1753...  9.5909 sec/batch
# Epoch: 1/20...  Training Step: 49...  Training loss: 3.1646...  9.6399 sec/batch
# Epoch: 1/20...  Training Step: 50...  Training loss: 3.1646...  10.4190 sec/batch
# Epoch: 1/20...  Training Step: 51...  Training loss: 3.1555...  10.8582 sec/batch
# Epoch: 1/20...  Training Step: 52...  Training loss: 3.1507...  11.5643 sec/batch
# Epoch: 1/20...  Training Step: 53...  Training loss: 3.1557...  11.7053 sec/batch
# Epoch: 1/20...  Training Step: 54...  Training loss: 3.1387...  10.1223 sec/batch
# Epoch: 1/20...  Training Step: 55...  Training loss: 3.1571...  9.6845 sec/batch
# Epoch: 1/20...  Training Step: 56...  Training loss: 3.1269...  9.5339 sec/batch
# Epoch: 1/20...  Training Step: 57...  Training loss: 3.1504...  9.8376 sec/batch
# Epoch: 1/20...  Training Step: 58...  Training loss: 3.1415...  9.9717 sec/batch
# Epoch: 1/20...  Training Step: 59...  Training loss: 3.1326...  9.8986 sec/batch
# Epoch: 1/20...  Training Step: 60...  Training loss: 3.1493...  10.0042 sec/batch
# Epoch: 1/20...  Training Step: 61...  Training loss: 3.1471...  9.7203 sec/batch
# Epoch: 1/20...  Training Step: 62...  Training loss: 3.1610...  9.7065 sec/batch
# Epoch: 1/20...  Training Step: 63...  Training loss: 3.1617...  9.8506 sec/batch
# Epoch: 1/20...  Training Step: 64...  Training loss: 3.1230...  9.6728 sec/batch
# Epoch: 1/20...  Training Step: 65...  Training loss: 3.1228...  9.8401 sec/batch
# Epoch: 1/20...  Training Step: 66...  Training loss: 3.1524...  11.3646 sec/batch
# Epoch: 1/20...  Training Step: 67...  Training loss: 3.1400...  12.6915 sec/batch
# Epoch: 1/20...  Training Step: 68...  Training loss: 3.0938...  12.2962 sec/batch
# Epoch: 1/20...  Training Step: 69...  Training loss: 3.1169...  11.6374 sec/batch
# Epoch: 1/20...  Training Step: 70...  Training loss: 3.1372...  11.6608 sec/batch
# Epoch: 1/20...  Training Step: 71...  Training loss: 3.1285...  10.2158 sec/batch
# Epoch: 1/20...  Training Step: 72...  Training loss: 3.1439...  10.3629 sec/batch
# Epoch: 1/20...  Training Step: 73...  Training loss: 3.1219...  9.9541 sec/batch
# Epoch: 1/20...  Training Step: 74...  Training loss: 3.1285...  10.2443 sec/batch
# Epoch: 1/20...  Training Step: 75...  Training loss: 3.1282...  9.8446 sec/batch
# Epoch: 1/20...  Training Step: 76...  Training loss: 3.1359...  9.7568 sec/batch
# Epoch: 1/20...  Training Step: 77...  Training loss: 3.1244...  9.9628 sec/batch
# Epoch: 1/20...  Training Step: 78...  Training loss: 3.1235...  9.7995 sec/batch
# Epoch: 1/20...  Training Step: 79...  Training loss: 3.1169...  9.6359 sec/batch
# Epoch: 1/20...  Training Step: 80...  Training loss: 3.1028...  9.6444 sec/batch
# Epoch: 1/20...  Training Step: 81...  Training loss: 3.1121...  9.8110 sec/batch
# Epoch: 1/20...  Training Step: 82...  Training loss: 3.1127...  10.0782 sec/batch
# Epoch: 1/20...  Training Step: 83...  Training loss: 3.1200...  10.4570 sec/batch
# Epoch: 1/20...  Training Step: 84...  Training loss: 3.1124...  11.7759 sec/batch
# Epoch: 1/20...  Training Step: 85...  Training loss: 3.0900...  10.9716 sec/batch
# Epoch: 1/20...  Training Step: 86...  Training loss: 3.0966...  12.2187 sec/batch
# Epoch: 1/20...  Training Step: 87...  Training loss: 3.0912...  10.1483 sec/batch
# Epoch: 1/20...  Training Step: 88...  Training loss: 3.0868...  9.8296 sec/batch
# Epoch: 1/20...  Training Step: 89...  Training loss: 3.1015...  11.1666 sec/batch
# Epoch: 1/20...  Training Step: 90...  Training loss: 3.1018...  9.9579 sec/batch
# Epoch: 1/20...  Training Step: 91...  Training loss: 3.0921...  9.8866 sec/batch
# Epoch: 1/20...  Training Step: 92...  Training loss: 3.0849...  9.8476 sec/batch
# Epoch: 1/20...  Training Step: 93...  Training loss: 3.0829...  9.9762 sec/batch
# Epoch: 1/20...  Training Step: 94...  Training loss: 3.0792...  9.6479 sec/batch
# Epoch: 1/20...  Training Step: 95...  Training loss: 3.0712...  9.5309 sec/batch
# Epoch: 1/20...  Training Step: 96...  Training loss: 3.0651...  9.7439 sec/batch
# Epoch: 1/20...  Training Step: 97...  Training loss: 3.0719...  9.5614 sec/batch
# Epoch: 1/20...  Training Step: 98...  Training loss: 3.0649...  9.9812 sec/batch
# Epoch: 1/20...  Training Step: 99...  Training loss: 3.0815...  10.0604 sec/batch
# Epoch: 1/20...  Training Step: 100...  Training loss: 3.0622...  9.7645 sec/batch
# Epoch: 1/20...  Training Step: 101...  Training loss: 3.0694...  9.8607 sec/batch
# Epoch: 1/20...  Training Step: 102...  Training loss: 3.0653...  9.6440 sec/batch
# Epoch: 1/20...  Training Step: 103...  Training loss: 3.0654...  9.7131 sec/batch
# Epoch: 1/20...  Training Step: 104...  Training loss: 3.0477...  9.6820 sec/batch
# Epoch: 1/20...  Training Step: 105...  Training loss: 3.0502...  9.8886 sec/batch
# Epoch: 1/20...  Training Step: 106...  Training loss: 3.0559...  11.1369 sec/batch
# Epoch: 1/20...  Training Step: 107...  Training loss: 3.0259...  10.1164 sec/batch
# Epoch: 1/20...  Training Step: 108...  Training loss: 3.0286...  11.4632 sec/batch
# Epoch: 1/20...  Training Step: 109...  Training loss: 3.0319...  10.2402 sec/batch
# Epoch: 1/20...  Training Step: 110...  Training loss: 2.9905...  10.5972 sec/batch
# Epoch: 1/20...  Training Step: 111...  Training loss: 3.0021...  10.0802 sec/batch
# Epoch: 1/20...  Training Step: 112...  Training loss: 3.0080...  9.9797 sec/batch
# Epoch: 1/20...  Training Step: 113...  Training loss: 2.9871...  10.5395 sec/batch
# Epoch: 1/20...  Training Step: 114...  Training loss: 2.9803...  9.8101 sec/batch
# Epoch: 1/20...  Training Step: 115...  Training loss: 2.9796...  9.9068 sec/batch
# Epoch: 1/20...  Training Step: 116...  Training loss: 2.9704...  9.4848 sec/batch
# Epoch: 1/20...  Training Step: 117...  Training loss: 2.9697...  9.1196 sec/batch
# Epoch: 1/20...  Training Step: 118...  Training loss: 2.9781...  9.3192 sec/batch
# Epoch: 1/20...  Training Step: 119...  Training loss: 2.9698...  9.2332 sec/batch
# Epoch: 1/20...  Training Step: 120...  Training loss: 2.9424...  9.2588 sec/batch
# Epoch: 1/20...  Training Step: 121...  Training loss: 2.9789...  10.0619 sec/batch
# Epoch: 1/20...  Training Step: 122...  Training loss: 2.9765...  9.6645 sec/batch
# Epoch: 1/20...  Training Step: 123...  Training loss: 2.9775...  9.7360 sec/batch
# Epoch: 1/20...  Training Step: 124...  Training loss: 2.9654...  9.7491 sec/batch
# Epoch: 1/20...  Training Step: 125...  Training loss: 2.9352...  9.6855 sec/batch
# Epoch: 1/20...  Training Step: 126...  Training loss: 2.9154...  9.2136 sec/batch
# Epoch: 1/20...  Training Step: 127...  Training loss: 2.9415...  10.1027 sec/batch
# Epoch: 1/20...  Training Step: 128...  Training loss: 2.9352...  9.2997 sec/batch
# Epoch: 1/20...  Training Step: 129...  Training loss: 2.9090...  9.0956 sec/batch
# Epoch: 1/20...  Training Step: 130...  Training loss: 2.9048...  9.1517 sec/batch
# Epoch: 1/20...  Training Step: 131...  Training loss: 2.9065...  9.1371 sec/batch
# Epoch: 1/20...  Training Step: 132...  Training loss: 2.8583...  9.3698 sec/batch
# Epoch: 1/20...  Training Step: 133...  Training loss: 2.8741...  9.7350 sec/batch
# Epoch: 1/20...  Training Step: 134...  Training loss: 2.8541...  9.1176 sec/batch
# Epoch: 1/20...  Training Step: 135...  Training loss: 2.8289...  9.2612 sec/batch
# Epoch: 1/20...  Training Step: 136...  Training loss: 2.8222...  9.3769 sec/batch
# Epoch: 1/20...  Training Step: 137...  Training loss: 2.8231...  9.4403 sec/batch
# Epoch: 1/20...  Training Step: 138...  Training loss: 2.8257...  9.5474 sec/batch
# Epoch: 1/20...  Training Step: 139...  Training loss: 2.8449...  9.8637 sec/batch
# Epoch: 1/20...  Training Step: 140...  Training loss: 2.8194...  9.4953 sec/batch
# Epoch: 1/20...  Training Step: 141...  Training loss: 2.8280...  9.8120 sec/batch
# Epoch: 1/20...  Training Step: 142...  Training loss: 2.7877...  9.4373 sec/batch
# Epoch: 1/20...  Training Step: 143...  Training loss: 2.7887...  11.2701 sec/batch
# Epoch: 1/20...  Training Step: 144...  Training loss: 2.7848...  12.7310 sec/batch
# Epoch: 1/20...  Training Step: 145...  Training loss: 2.7746...  10.0957 sec/batch
# Epoch: 1/20...  Training Step: 146...  Training loss: 2.7808...  10.9129 sec/batch
# Epoch: 1/20...  Training Step: 147...  Training loss: 2.7648...  10.1598 sec/batch
# Epoch: 1/20...  Training Step: 148...  Training loss: 2.7797...  10.7489 sec/batch
# Epoch: 1/20...  Training Step: 149...  Training loss: 2.7327...  10.3534 sec/batch
# Epoch: 1/20...  Training Step: 150...  Training loss: 2.7293...  9.9712 sec/batch
# Epoch: 1/20...  Training Step: 151...  Training loss: 2.7674...  9.7255 sec/batch
# Epoch: 1/20...  Training Step: 152...  Training loss: 2.7629...  9.7530 sec/batch
# Epoch: 1/20...  Training Step: 153...  Training loss: 2.7161...  9.7174 sec/batch
# Epoch: 1/20...  Training Step: 154...  Training loss: 2.7130...  9.7175 sec/batch
# Epoch: 1/20...  Training Step: 155...  Training loss: 2.6836...  9.5249 sec/batch
# Epoch: 1/20...  Training Step: 156...  Training loss: 2.6834...  9.6455 sec/batch
# Epoch: 1/20...  Training Step: 157...  Training loss: 2.6653...  9.8441 sec/batch
# Epoch: 1/20...  Training Step: 158...  Training loss: 2.6598...  9.6244 sec/batch
# Epoch: 1/20...  Training Step: 159...  Training loss: 2.6366...  9.8106 sec/batch
# Epoch: 1/20...  Training Step: 160...  Training loss: 2.6696...  9.6106 sec/batch
# Epoch: 1/20...  Training Step: 161...  Training loss: 2.6495...  9.6740 sec/batch
# Epoch: 1/20...  Training Step: 162...  Training loss: 2.6208...  10.0497 sec/batch
# Epoch: 1/20...  Training Step: 163...  Training loss: 2.5984...  9.8901 sec/batch
# Epoch: 1/20...  Training Step: 164...  Training loss: 2.6159...  10.2353 sec/batch
# Epoch: 1/20...  Training Step: 165...  Training loss: 2.6174...  10.1188 sec/batch
# Epoch: 1/20...  Training Step: 166...  Training loss: 2.6075...  11.0894 sec/batch
# Epoch: 1/20...  Training Step: 167...  Training loss: 2.6020...  11.5828 sec/batch
# Epoch: 1/20...  Training Step: 168...  Training loss: 2.5941...  9.6270 sec/batch
# Epoch: 1/20...  Training Step: 169...  Training loss: 2.5921...  9.6274 sec/batch
# Epoch: 1/20...  Training Step: 170...  Training loss: 2.5602...  9.7150 sec/batch
# Epoch: 1/20...  Training Step: 171...  Training loss: 2.5799...  9.5704 sec/batch
# Epoch: 1/20...  Training Step: 172...  Training loss: 2.5961...  9.7061 sec/batch
# Epoch: 1/20...  Training Step: 173...  Training loss: 2.6524...  9.9141 sec/batch
# Epoch: 1/20...  Training Step: 174...  Training loss: 2.6390...  9.8136 sec/batch
# Epoch: 1/20...  Training Step: 175...  Training loss: 2.5926...  9.9414 sec/batch
# Epoch: 1/20...  Training Step: 176...  Training loss: 2.5504...  10.5052 sec/batch
# Epoch: 1/20...  Training Step: 177...  Training loss: 2.5383...  10.1062 sec/batch
# Epoch: 1/20...  Training Step: 178...  Training loss: 2.5187...  10.6717 sec/batch
# Epoch: 1/20...  Training Step: 179...  Training loss: 2.5153...  10.5280 sec/batch
# Epoch: 1/20...  Training Step: 180...  Training loss: 2.5079...  9.9732 sec/batch
# Epoch: 1/20...  Training Step: 181...  Training loss: 2.5148...  10.1124 sec/batch
# Epoch: 1/20...  Training Step: 182...  Training loss: 2.5120...  11.4251 sec/batch
# Epoch: 1/20...  Training Step: 183...  Training loss: 2.5004...  9.4928 sec/batch
# Epoch: 1/20...  Training Step: 184...  Training loss: 2.5306...  9.6750 sec/batch
# Epoch: 1/20...  Training Step: 185...  Training loss: 2.5600...  9.7501 sec/batch
# Epoch: 1/20...  Training Step: 186...  Training loss: 2.5100...  10.1958 sec/batch
# Epoch: 1/20...  Training Step: 187...  Training loss: 2.4770...  9.8321 sec/batch
# Epoch: 1/20...  Training Step: 188...  Training loss: 2.4799...  10.0057 sec/batch
# Epoch: 1/20...  Training Step: 189...  Training loss: 2.4753...  9.7210 sec/batch
# Epoch: 1/20...  Training Step: 190...  Training loss: 2.4779...  9.8306 sec/batch
# Epoch: 1/20...  Training Step: 191...  Training loss: 2.4837...  10.4016 sec/batch
# Epoch: 1/20...  Training Step: 192...  Training loss: 2.4564...  10.0962 sec/batch
# Epoch: 1/20...  Training Step: 193...  Training loss: 2.4762...  10.0537 sec/batch
# Epoch: 1/20...  Training Step: 194...  Training loss: 2.4669...  9.8555 sec/batch
# Epoch: 1/20...  Training Step: 195...  Training loss: 2.4563...  9.8471 sec/batch
# Epoch: 1/20...  Training Step: 196...  Training loss: 2.4524...  10.0697 sec/batch
# Epoch: 1/20...  Training Step: 197...  Training loss: 2.4533...  9.8431 sec/batch
# Epoch: 1/20...  Training Step: 198...  Training loss: 2.4338...  9.8366 sec/batch
# Epoch: 2/20...  Training Step: 199...  Training loss: 2.5339...  9.8065 sec/batch
# Epoch: 2/20...  Training Step: 200...  Training loss: 2.4241...  9.8841 sec/batch
# Epoch: 2/20...  Training Step: 201...  Training loss: 2.4225...  10.0278 sec/batch
# Epoch: 2/20...  Training Step: 202...  Training loss: 2.4374...  9.6199 sec/batch
# Epoch: 2/20...  Training Step: 203...  Training loss: 2.4371...  9.6655 sec/batch
# Epoch: 2/20...  Training Step: 204...  Training loss: 2.4289...  9.6355 sec/batch
# Epoch: 2/20...  Training Step: 205...  Training loss: 2.4276...  9.9862 sec/batch
# Epoch: 2/20...  Training Step: 206...  Training loss: 2.4404...  9.6395 sec/batch
# Epoch: 2/20...  Training Step: 207...  Training loss: 2.4513...  9.8742 sec/batch
# Epoch: 2/20...  Training Step: 208...  Training loss: 2.4198...  9.9076 sec/batch
# Epoch: 2/20...  Training Step: 209...  Training loss: 2.4280...  9.6470 sec/batch
# Epoch: 2/20...  Training Step: 210...  Training loss: 2.4237...  9.6855 sec/batch
# Epoch: 2/20...  Training Step: 211...  Training loss: 2.4200...  9.7795 sec/batch
# Epoch: 2/20...  Training Step: 212...  Training loss: 2.4561...  9.7078 sec/batch
# Epoch: 2/20...  Training Step: 213...  Training loss: 2.4238...  10.9808 sec/batch
# Epoch: 2/20...  Training Step: 214...  Training loss: 2.4291...  10.2398 sec/batch
# Epoch: 2/20...  Training Step: 215...  Training loss: 2.4163...  9.8836 sec/batch
# Epoch: 2/20...  Training Step: 216...  Training loss: 2.4424...  9.7890 sec/batch
# Epoch: 2/20...  Training Step: 217...  Training loss: 2.4153...  9.9734 sec/batch
# Epoch: 2/20...  Training Step: 218...  Training loss: 2.3849...  9.9772 sec/batch
# Epoch: 2/20...  Training Step: 219...  Training loss: 2.4007...  12.1704 sec/batch
# Epoch: 2/20...  Training Step: 220...  Training loss: 2.4352...  11.9407 sec/batch
# Epoch: 2/20...  Training Step: 221...  Training loss: 2.4039...  11.7384 sec/batch
# Epoch: 2/20...  Training Step: 222...  Training loss: 2.3886...  11.8334 sec/batch
# Epoch: 2/20...  Training Step: 223...  Training loss: 2.3812...  10.8988 sec/batch
# Epoch: 2/20...  Training Step: 224...  Training loss: 2.3953...  10.5636 sec/batch
# Epoch: 2/20...  Training Step: 225...  Training loss: 2.3796...  9.8572 sec/batch
# Epoch: 2/20...  Training Step: 226...  Training loss: 2.3814...  10.6213 sec/batch
# Epoch: 2/20...  Training Step: 227...  Training loss: 2.3961...  10.0522 sec/batch
# Epoch: 2/20...  Training Step: 228...  Training loss: 2.3911...  9.6915 sec/batch
# Epoch: 2/20...  Training Step: 229...  Training loss: 2.3988...  9.5799 sec/batch
# Epoch: 2/20...  Training Step: 230...  Training loss: 2.3607...  9.6970 sec/batch
# Epoch: 2/20...  Training Step: 231...  Training loss: 2.3591...  9.7041 sec/batch
# Epoch: 2/20...  Training Step: 232...  Training loss: 2.3869...  10.4709 sec/batch
# Epoch: 2/20...  Training Step: 233...  Training loss: 2.3529...  11.3131 sec/batch
# Epoch: 2/20...  Training Step: 234...  Training loss: 2.3705...  9.7270 sec/batch
# Epoch: 2/20...  Training Step: 235...  Training loss: 2.3515...  9.3392 sec/batch
# Epoch: 2/20...  Training Step: 236...  Training loss: 2.3200...  9.5487 sec/batch
# Epoch: 2/20...  Training Step: 237...  Training loss: 2.3375...  9.5189 sec/batch
# Epoch: 2/20...  Training Step: 238...  Training loss: 2.3407...  9.9191 sec/batch
# Epoch: 2/20...  Training Step: 239...  Training loss: 2.3351...  9.6875 sec/batch
# Epoch: 2/20...  Training Step: 240...  Training loss: 2.3341...  10.5786 sec/batch
# Epoch: 2/20...  Training Step: 241...  Training loss: 2.3226...  10.0662 sec/batch
# Epoch: 2/20...  Training Step: 242...  Training loss: 2.3200...  9.6840 sec/batch
# Epoch: 2/20...  Training Step: 243...  Training loss: 2.3300...  9.5189 sec/batch
# Epoch: 2/20...  Training Step: 244...  Training loss: 2.2895...  9.6940 sec/batch
# Epoch: 2/20...  Training Step: 245...  Training loss: 2.3490...  9.4403 sec/batch
# Epoch: 2/20...  Training Step: 246...  Training loss: 2.3202...  9.3683 sec/batch
# Epoch: 2/20...  Training Step: 247...  Training loss: 2.3260...  9.6274 sec/batch
# Epoch: 2/20...  Training Step: 248...  Training loss: 2.3399...  9.5874 sec/batch
# Epoch: 2/20...  Training Step: 249...  Training loss: 2.2963...  9.4223 sec/batch
# Epoch: 2/20...  Training Step: 250...  Training loss: 2.3423...  9.2452 sec/batch
# Epoch: 2/20...  Training Step: 251...  Training loss: 2.3073...  9.4278 sec/batch
# Epoch: 2/20...  Training Step: 252...  Training loss: 2.3068...  9.9116 sec/batch
# Epoch: 2/20...  Training Step: 253...  Training loss: 2.3031...  9.9877 sec/batch
# Epoch: 2/20...  Training Step: 254...  Training loss: 2.3141...  9.8311 sec/batch
# Epoch: 2/20...  Training Step: 255...  Training loss: 2.3163...  9.6409 sec/batch
# Epoch: 2/20...  Training Step: 256...  Training loss: 2.2947...  9.6610 sec/batch
# Epoch: 2/20...  Training Step: 257...  Training loss: 2.2970...  9.5149 sec/batch
# Epoch: 2/20...  Training Step: 258...  Training loss: 2.3286...  9.2317 sec/batch
# Epoch: 2/20...  Training Step: 259...  Training loss: 2.2999...  9.3347 sec/batch
# Epoch: 2/20...  Training Step: 260...  Training loss: 2.3112...  9.8811 sec/batch
# Epoch: 2/20...  Training Step: 261...  Training loss: 2.3200...  9.5720 sec/batch
# Epoch: 2/20...  Training Step: 262...  Training loss: 2.3017...  10.3759 sec/batch
# Epoch: 2/20...  Training Step: 263...  Training loss: 2.2819...  9.7920 sec/batch
# Epoch: 2/20...  Training Step: 264...  Training loss: 2.3143...  9.5514 sec/batch
# Epoch: 2/20...  Training Step: 265...  Training loss: 2.2918...  9.5844 sec/batch
# Epoch: 2/20...  Training Step: 266...  Training loss: 2.2587...  10.7252 sec/batch
# Epoch: 2/20...  Training Step: 267...  Training loss: 2.2744...  9.8101 sec/batch
# Epoch: 2/20...  Training Step: 268...  Training loss: 2.2831...  9.8646 sec/batch
# Epoch: 2/20...  Training Step: 269...  Training loss: 2.3053...  10.8084 sec/batch
# Epoch: 2/20...  Training Step: 270...  Training loss: 2.2855...  10.6871 sec/batch
# Epoch: 2/20...  Training Step: 271...  Training loss: 2.2942...  10.4766 sec/batch
# Epoch: 2/20...  Training Step: 272...  Training loss: 2.2627...  9.8551 sec/batch
# Epoch: 2/20...  Training Step: 273...  Training loss: 2.2773...  10.3824 sec/batch
# Epoch: 2/20...  Training Step: 274...  Training loss: 2.3088...  11.6536 sec/batch
# Epoch: 2/20...  Training Step: 275...  Training loss: 2.2654...  10.7324 sec/batch
# Epoch: 2/20...  Training Step: 276...  Training loss: 2.2777...  10.8384 sec/batch
# Epoch: 2/20...  Training Step: 277...  Training loss: 2.2477...  10.2840 sec/batch
# Epoch: 2/20...  Training Step: 278...  Training loss: 2.2553...  9.7985 sec/batch
# Epoch: 2/20...  Training Step: 279...  Training loss: 2.2368...  9.3412 sec/batch
# Epoch: 2/20...  Training Step: 280...  Training loss: 2.2726...  10.5254 sec/batch
# Epoch: 2/20...  Training Step: 281...  Training loss: 2.2318...  12.9862 sec/batch
# Epoch: 2/20...  Training Step: 282...  Training loss: 2.2266...  12.6561 sec/batch
# Epoch: 2/20...  Training Step: 283...  Training loss: 2.2114...  12.5462 sec/batch
# Epoch: 2/20...  Training Step: 284...  Training loss: 2.2421...  11.9931 sec/batch
# Epoch: 2/20...  Training Step: 285...  Training loss: 2.2351...  10.3934 sec/batch
# Epoch: 2/20...  Training Step: 286...  Training loss: 2.2375...  10.2193 sec/batch
# Epoch: 2/20...  Training Step: 287...  Training loss: 2.2170...  11.6481 sec/batch
# Epoch: 2/20...  Training Step: 288...  Training loss: 2.2495...  10.4537 sec/batch
# Epoch: 2/20...  Training Step: 289...  Training loss: 2.2176...  9.8566 sec/batch
# Epoch: 2/20...  Training Step: 290...  Training loss: 2.2306...  10.8641 sec/batch
# Epoch: 2/20...  Training Step: 291...  Training loss: 2.2027...  13.4551 sec/batch
# Epoch: 2/20...  Training Step: 292...  Training loss: 2.2162...  12.8654 sec/batch
# Epoch: 2/20...  Training Step: 293...  Training loss: 2.2045...  10.0152 sec/batch
# Epoch: 2/20...  Training Step: 294...  Training loss: 2.2179...  9.8901 sec/batch
# Epoch: 2/20...  Training Step: 295...  Training loss: 2.2084...  10.8415 sec/batch
# Epoch: 2/20...  Training Step: 296...  Training loss: 2.2144...  9.6320 sec/batch
# Epoch: 2/20...  Training Step: 297...  Training loss: 2.1989...  10.6769 sec/batch
# Epoch: 2/20...  Training Step: 298...  Training loss: 2.1944...  10.6597 sec/batch
# Epoch: 2/20...  Training Step: 299...  Training loss: 2.2271...  9.8546 sec/batch
# Epoch: 2/20...  Training Step: 300...  Training loss: 2.2138...  10.3855 sec/batch
# Epoch: 2/20...  Training Step: 301...  Training loss: 2.1981...  11.4162 sec/batch
# Epoch: 2/20...  Training Step: 302...  Training loss: 2.1999...  10.8018 sec/batch
# Epoch: 2/20...  Training Step: 303...  Training loss: 2.2026...  10.5385 sec/batch
# Epoch: 2/20...  Training Step: 304...  Training loss: 2.2029...  10.5531 sec/batch
# Epoch: 2/20...  Training Step: 305...  Training loss: 2.1966...  12.5914 sec/batch
# Epoch: 2/20...  Training Step: 306...  Training loss: 2.2291...  13.3304 sec/batch
# Epoch: 2/20...  Training Step: 307...  Training loss: 2.2166...  10.8201 sec/batch
# Epoch: 2/20...  Training Step: 308...  Training loss: 2.1909...  10.8147 sec/batch
# Epoch: 2/20...  Training Step: 309...  Training loss: 2.2052...  11.0991 sec/batch
# Epoch: 2/20...  Training Step: 310...  Training loss: 2.2206...  10.9263 sec/batch
# Epoch: 2/20...  Training Step: 311...  Training loss: 2.1830...  10.6160 sec/batch
# Epoch: 2/20...  Training Step: 312...  Training loss: 2.1884...  10.7402 sec/batch
# Epoch: 2/20...  Training Step: 313...  Training loss: 2.1823...  10.4970 sec/batch
# Epoch: 2/20...  Training Step: 314...  Training loss: 2.1542...  10.3329 sec/batch
# Epoch: 2/20...  Training Step: 315...  Training loss: 2.1944...  13.0052 sec/batch
# Epoch: 2/20...  Training Step: 316...  Training loss: 2.1881...  10.1903 sec/batch
# Epoch: 2/20...  Training Step: 317...  Training loss: 2.2085...  10.4900 sec/batch
# Epoch: 2/20...  Training Step: 318...  Training loss: 2.1892...  10.3999 sec/batch
# Epoch: 2/20...  Training Step: 319...  Training loss: 2.2101...  11.0705 sec/batch
# Epoch: 2/20...  Training Step: 320...  Training loss: 2.1717...  10.2558 sec/batch
# Epoch: 2/20...  Training Step: 321...  Training loss: 2.1677...  10.1943 sec/batch
# Epoch: 2/20...  Training Step: 322...  Training loss: 2.2056...  10.6836 sec/batch
# Epoch: 2/20...  Training Step: 323...  Training loss: 2.1719...  12.0295 sec/batch
# Epoch: 2/20...  Training Step: 324...  Training loss: 2.1442...  9.4163 sec/batch
# Epoch: 2/20...  Training Step: 325...  Training loss: 2.1826...  9.2292 sec/batch
# Epoch: 2/20...  Training Step: 326...  Training loss: 2.1898...  10.1718 sec/batch
# Epoch: 2/20...  Training Step: 327...  Training loss: 2.1749...  10.2233 sec/batch
# Epoch: 2/20...  Training Step: 328...  Training loss: 2.1785...  10.2110 sec/batch
# Epoch: 2/20...  Training Step: 329...  Training loss: 2.1558...  10.3569 sec/batch
# Epoch: 2/20...  Training Step: 330...  Training loss: 2.1394...  10.1849 sec/batch
# Epoch: 2/20...  Training Step: 331...  Training loss: 2.1724...  10.4660 sec/batch
# Epoch: 2/20...  Training Step: 332...  Training loss: 2.1749...  10.4910 sec/batch
# Epoch: 2/20...  Training Step: 333...  Training loss: 2.1479...  10.5421 sec/batch
# Epoch: 2/20...  Training Step: 334...  Training loss: 2.1767...  10.2168 sec/batch
# Epoch: 2/20...  Training Step: 335...  Training loss: 2.1568...  10.3229 sec/batch
# Epoch: 2/20...  Training Step: 336...  Training loss: 2.1587...  10.1973 sec/batch
# Epoch: 2/20...  Training Step: 337...  Training loss: 2.1954...  10.3184 sec/batch
# Epoch: 2/20...  Training Step: 338...  Training loss: 2.1412...  10.2359 sec/batch
# Epoch: 2/20...  Training Step: 339...  Training loss: 2.1790...  10.3779 sec/batch
# Epoch: 2/20...  Training Step: 340...  Training loss: 2.1456...  10.5090 sec/batch
# Epoch: 2/20...  Training Step: 341...  Training loss: 2.1432...  10.3534 sec/batch
# Epoch: 2/20...  Training Step: 342...  Training loss: 2.1453...  10.2634 sec/batch
# Epoch: 2/20...  Training Step: 343...  Training loss: 2.1364...  10.5300 sec/batch
# Epoch: 2/20...  Training Step: 344...  Training loss: 2.1675...  9.1811 sec/batch
# Epoch: 2/20...  Training Step: 345...  Training loss: 2.1515...  9.1202 sec/batch
# Epoch: 2/20...  Training Step: 346...  Training loss: 2.1674...  9.1366 sec/batch
# Epoch: 2/20...  Training Step: 347...  Training loss: 2.1463...  9.3612 sec/batch
# Epoch: 2/20...  Training Step: 348...  Training loss: 2.1241...  10.0357 sec/batch
# Epoch: 2/20...  Training Step: 349...  Training loss: 2.1468...  9.4756 sec/batch
# Epoch: 2/20...  Training Step: 350...  Training loss: 2.1718...  9.5924 sec/batch
# Epoch: 2/20...  Training Step: 351...  Training loss: 2.1583...  10.0457 sec/batch
# Epoch: 2/20...  Training Step: 352...  Training loss: 2.1419...  9.5705 sec/batch
# Epoch: 2/20...  Training Step: 353...  Training loss: 2.1168...  9.5045 sec/batch
# Epoch: 2/20...  Training Step: 354...  Training loss: 2.1252...  9.3193 sec/batch
# Epoch: 2/20...  Training Step: 355...  Training loss: 2.1284...  9.4628 sec/batch
# Epoch: 2/20...  Training Step: 356...  Training loss: 2.1349...  11.4582 sec/batch
# Epoch: 2/20...  Training Step: 357...  Training loss: 2.1003...  12.2111 sec/batch
# Epoch: 2/20...  Training Step: 358...  Training loss: 2.1701...  11.2185 sec/batch
# Epoch: 2/20...  Training Step: 359...  Training loss: 2.1450...  10.7757 sec/batch
# Epoch: 2/20...  Training Step: 360...  Training loss: 2.1197...  10.4635 sec/batch
# Epoch: 2/20...  Training Step: 361...  Training loss: 2.1370...  10.8943 sec/batch
# Epoch: 2/20...  Training Step: 362...  Training loss: 2.1275...  10.6321 sec/batch
# Epoch: 2/20...  Training Step: 363...  Training loss: 2.1250...  10.6626 sec/batch
# Epoch: 2/20...  Training Step: 364...  Training loss: 2.1188...  10.6341 sec/batch
# Epoch: 2/20...  Training Step: 365...  Training loss: 2.1205...  10.7532 sec/batch
# Epoch: 2/20...  Training Step: 366...  Training loss: 2.1441...  11.4081 sec/batch
# Epoch: 2/20...  Training Step: 367...  Training loss: 2.1155...  11.2145 sec/batch
# Epoch: 2/20...  Training Step: 368...  Training loss: 2.0996...  12.0330 sec/batch
# Epoch: 2/20...  Training Step: 369...  Training loss: 2.1031...  10.7313 sec/batch
# Epoch: 2/20...  Training Step: 370...  Training loss: 2.1266...  10.6986 sec/batch
# Epoch: 2/20...  Training Step: 371...  Training loss: 2.1355...  10.7116 sec/batch
# Epoch: 2/20...  Training Step: 372...  Training loss: 2.1256...  10.6206 sec/batch
# Epoch: 2/20...  Training Step: 373...  Training loss: 2.1126...  10.9033 sec/batch
# Epoch: 2/20...  Training Step: 374...  Training loss: 2.1074...  10.5611 sec/batch
# Epoch: 2/20...  Training Step: 375...  Training loss: 2.0991...  10.7223 sec/batch
# Epoch: 2/20...  Training Step: 376...  Training loss: 2.1129...  10.6026 sec/batch
# Epoch: 2/20...  Training Step: 377...  Training loss: 2.0905...  10.6840 sec/batch
# Epoch: 2/20...  Training Step: 378...  Training loss: 2.0679...  10.7672 sec/batch
# Epoch: 2/20...  Training Step: 379...  Training loss: 2.0802...  12.2632 sec/batch
# Epoch: 2/20...  Training Step: 380...  Training loss: 2.0926...  12.0370 sec/batch
# Epoch: 2/20...  Training Step: 381...  Training loss: 2.0981...  10.5436 sec/batch
# Epoch: 2/20...  Training Step: 382...  Training loss: 2.1151...  11.4508 sec/batch
# Epoch: 2/20...  Training Step: 383...  Training loss: 2.1108...  10.2523 sec/batch
# Epoch: 2/20...  Training Step: 384...  Training loss: 2.0783...  10.0652 sec/batch
# Epoch: 2/20...  Training Step: 385...  Training loss: 2.0884...  10.0583 sec/batch
# Epoch: 2/20...  Training Step: 386...  Training loss: 2.0591...  12.2368 sec/batch
# Epoch: 2/20...  Training Step: 387...  Training loss: 2.0635...  11.0397 sec/batch
# Epoch: 2/20...  Training Step: 388...  Training loss: 2.0735...  11.5932 sec/batch
# Epoch: 2/20...  Training Step: 389...  Training loss: 2.0932...  11.6388 sec/batch
# Epoch: 2/20...  Training Step: 390...  Training loss: 2.0566...  11.1189 sec/batch
# Epoch: 2/20...  Training Step: 391...  Training loss: 2.0916...  10.6581 sec/batch
# Epoch: 2/20...  Training Step: 392...  Training loss: 2.0709...  10.4880 sec/batch
# Epoch: 2/20...  Training Step: 393...  Training loss: 2.0598...  10.6087 sec/batch
# Epoch: 2/20...  Training Step: 394...  Training loss: 2.0727...  10.5280 sec/batch
# Epoch: 2/20...  Training Step: 395...  Training loss: 2.0664...  10.4530 sec/batch
# Epoch: 2/20...  Training Step: 396...  Training loss: 2.0475...  11.2360 sec/batch
# Epoch: 3/20...  Training Step: 397...  Training loss: 2.1527...  11.6678 sec/batch
# Epoch: 3/20...  Training Step: 398...  Training loss: 2.0423...  10.8988 sec/batch
# Epoch: 3/20...  Training Step: 399...  Training loss: 2.0556...  10.3895 sec/batch
# Epoch: 3/20...  Training Step: 400...  Training loss: 2.0575...  9.9982 sec/batch
# Epoch: 3/20...  Training Step: 401...  Training loss: 2.0562...  10.5375 sec/batch
# Epoch: 3/20...  Training Step: 402...  Training loss: 2.0284...  9.1878 sec/batch
# Epoch: 3/20...  Training Step: 403...  Training loss: 2.0665...  9.2762 sec/batch
# Epoch: 3/20...  Training Step: 404...  Training loss: 2.0547...  9.1086 sec/batch
# Epoch: 3/20...  Training Step: 405...  Training loss: 2.0866...  9.2427 sec/batch
# Epoch: 3/20...  Training Step: 406...  Training loss: 2.0602...  11.7219 sec/batch
# Epoch: 3/20...  Training Step: 407...  Training loss: 2.0340...  10.7323 sec/batch
# Epoch: 3/20...  Training Step: 408...  Training loss: 2.0399...  11.4136 sec/batch
# Epoch: 3/20...  Training Step: 409...  Training loss: 2.0497...  10.8838 sec/batch
# Epoch: 3/20...  Training Step: 410...  Training loss: 2.0833...  10.5630 sec/batch
# Epoch: 3/20...  Training Step: 411...  Training loss: 2.0392...  10.8172 sec/batch
# Epoch: 3/20...  Training Step: 412...  Training loss: 2.0376...  12.5556 sec/batch
# Epoch: 3/20...  Training Step: 413...  Training loss: 2.0426...  13.1334 sec/batch
# Epoch: 3/20...  Training Step: 414...  Training loss: 2.0855...  10.8728 sec/batch
# Epoch: 3/20...  Training Step: 415...  Training loss: 2.0583...  11.7500 sec/batch
# Epoch: 3/20...  Training Step: 416...  Training loss: 2.0431...  11.4446 sec/batch
# Epoch: 3/20...  Training Step: 417...  Training loss: 2.0371...  12.4292 sec/batch
# Epoch: 3/20...  Training Step: 418...  Training loss: 2.0945...  13.4851 sec/batch
# Epoch: 3/20...  Training Step: 419...  Training loss: 2.0445...  11.6673 sec/batch
# Epoch: 3/20...  Training Step: 420...  Training loss: 2.0382...  10.7992 sec/batch
# Epoch: 3/20...  Training Step: 421...  Training loss: 2.0344...  13.4446 sec/batch
# Epoch: 3/20...  Training Step: 422...  Training loss: 2.0090...  13.2581 sec/batch
# Epoch: 3/20...  Training Step: 423...  Training loss: 2.0055...  11.8985 sec/batch
# Epoch: 3/20...  Training Step: 424...  Training loss: 2.0461...  11.9551 sec/batch
# Epoch: 3/20...  Training Step: 425...  Training loss: 2.0646...  11.8770 sec/batch
# Epoch: 3/20...  Training Step: 426...  Training loss: 2.0425...  13.0498 sec/batch
# Epoch: 3/20...  Training Step: 427...  Training loss: 2.0401...  12.6766 sec/batch
# Epoch: 3/20...  Training Step: 428...  Training loss: 2.0141...  10.9600 sec/batch
# Epoch: 3/20...  Training Step: 429...  Training loss: 2.0311...  10.6731 sec/batch
# Epoch: 3/20...  Training Step: 430...  Training loss: 2.0629...  12.2854 sec/batch
# Epoch: 3/20...  Training Step: 431...  Training loss: 2.0067...  12.6374 sec/batch
# Epoch: 3/20...  Training Step: 432...  Training loss: 2.0186...  11.4232 sec/batch
# Epoch: 3/20...  Training Step: 433...  Training loss: 2.0178...  12.3027 sec/batch
# Epoch: 3/20...  Training Step: 434...  Training loss: 1.9798...  12.2452 sec/batch
# Epoch: 3/20...  Training Step: 435...  Training loss: 1.9807...  12.4009 sec/batch
# Epoch: 3/20...  Training Step: 436...  Training loss: 1.9860...  11.2855 sec/batch
# Epoch: 3/20...  Training Step: 437...  Training loss: 2.0015...  13.3840 sec/batch
# Epoch: 3/20...  Training Step: 438...  Training loss: 2.0120...  11.9646 sec/batch
# Epoch: 3/20...  Training Step: 439...  Training loss: 1.9994...  10.8577 sec/batch
# Epoch: 3/20...  Training Step: 440...  Training loss: 1.9863...  11.5356 sec/batch
# Epoch: 3/20...  Training Step: 441...  Training loss: 2.0149...  12.7460 sec/batch
# Epoch: 3/20...  Training Step: 442...  Training loss: 1.9579...  11.9802 sec/batch
# Epoch: 3/20...  Training Step: 443...  Training loss: 2.0173...  10.6286 sec/batch
# Epoch: 3/20...  Training Step: 444...  Training loss: 1.9866...  11.3226 sec/batch
# Epoch: 3/20...  Training Step: 445...  Training loss: 2.0088...  11.9490 sec/batch
# Epoch: 3/20...  Training Step: 446...  Training loss: 2.0398...  10.7807 sec/batch
# Epoch: 3/20...  Training Step: 447...  Training loss: 1.9685...  11.2920 sec/batch
# Epoch: 3/20...  Training Step: 448...  Training loss: 2.0510...  10.6897 sec/batch
# Epoch: 3/20...  Training Step: 449...  Training loss: 1.9984...  9.9982 sec/batch
# Epoch: 3/20...  Training Step: 450...  Training loss: 1.9934...  10.8483 sec/batch
# Epoch: 3/20...  Training Step: 451...  Training loss: 1.9956...  10.4715 sec/batch
# Epoch: 3/20...  Training Step: 452...  Training loss: 2.0112...  9.6154 sec/batch
# Epoch: 3/20...  Training Step: 453...  Training loss: 2.0076...  10.4024 sec/batch
# Epoch: 3/20...  Training Step: 454...  Training loss: 1.9900...  11.7534 sec/batch
# Epoch: 3/20...  Training Step: 455...  Training loss: 1.9782...  10.1660 sec/batch
# Epoch: 3/20...  Training Step: 456...  Training loss: 2.0225...  10.3185 sec/batch
# Epoch: 3/20...  Training Step: 457...  Training loss: 1.9946...  10.0703 sec/batch
# Epoch: 3/20...  Training Step: 458...  Training loss: 2.0309...  10.3970 sec/batch
# Epoch: 3/20...  Training Step: 459...  Training loss: 2.0208...  10.0182 sec/batch
# Epoch: 3/20...  Training Step: 460...  Training loss: 2.0023...  11.0310 sec/batch
# Epoch: 3/20...  Training Step: 461...  Training loss: 1.9840...  10.3854 sec/batch
# Epoch: 3/20...  Training Step: 462...  Training loss: 2.0191...  11.0103 sec/batch
# Epoch: 3/20...  Training Step: 463...  Training loss: 2.0000...  11.3831 sec/batch
# Epoch: 3/20...  Training Step: 464...  Training loss: 1.9693...  10.1778 sec/batch
# Epoch: 3/20...  Training Step: 465...  Training loss: 1.9643...  10.1605 sec/batch
# Epoch: 3/20...  Training Step: 466...  Training loss: 1.9838...  12.0716 sec/batch
# Epoch: 3/20...  Training Step: 467...  Training loss: 2.0233...  12.4133 sec/batch
# Epoch: 3/20...  Training Step: 468...  Training loss: 1.9937...  12.1446 sec/batch
# Epoch: 3/20...  Training Step: 469...  Training loss: 2.0011...  12.0260 sec/batch
# Epoch: 3/20...  Training Step: 470...  Training loss: 1.9773...  11.7884 sec/batch
# Epoch: 3/20...  Training Step: 471...  Training loss: 1.9670...  11.8891 sec/batch
# Epoch: 3/20...  Training Step: 472...  Training loss: 2.0093...  11.7530 sec/batch
# Epoch: 3/20...  Training Step: 473...  Training loss: 1.9751...  11.7373 sec/batch
# Epoch: 3/20...  Training Step: 474...  Training loss: 1.9836...  11.5983 sec/batch
# Epoch: 3/20...  Training Step: 475...  Training loss: 1.9426...  11.4757 sec/batch
# Epoch: 3/20...  Training Step: 476...  Training loss: 1.9563...  11.4036 sec/batch
# Epoch: 3/20...  Training Step: 477...  Training loss: 1.9385...  11.4496 sec/batch
# Epoch: 3/20...  Training Step: 478...  Training loss: 1.9947...  11.0989 sec/batch
# Epoch: 3/20...  Training Step: 479...  Training loss: 1.9455...  11.0634 sec/batch
# Epoch: 3/20...  Training Step: 480...  Training loss: 1.9585...  11.2970 sec/batch
# Epoch: 3/20...  Training Step: 481...  Training loss: 1.9256...  11.1126 sec/batch
# Epoch: 3/20...  Training Step: 482...  Training loss: 1.9459...  11.2030 sec/batch
# Epoch: 3/20...  Training Step: 483...  Training loss: 1.9589...  10.0225 sec/batch
# Epoch: 3/20...  Training Step: 484...  Training loss: 1.9488...  10.2994 sec/batch
# Epoch: 3/20...  Training Step: 485...  Training loss: 1.9288...  9.9778 sec/batch
# Epoch: 3/20...  Training Step: 486...  Training loss: 1.9745...  9.5324 sec/batch
# Epoch: 3/20...  Training Step: 487...  Training loss: 1.9355...  9.4795 sec/batch
# Epoch: 3/20...  Training Step: 488...  Training loss: 1.9567...  9.9043 sec/batch
# Epoch: 3/20...  Training Step: 489...  Training loss: 1.9275...  10.7662 sec/batch
# Epoch: 3/20...  Training Step: 490...  Training loss: 1.9391...  9.2788 sec/batch
# Epoch: 3/20...  Training Step: 491...  Training loss: 1.9344...  10.4685 sec/batch
# Epoch: 3/20...  Training Step: 492...  Training loss: 1.9470...  9.9526 sec/batch
# Epoch: 3/20...  Training Step: 493...  Training loss: 1.9464...  10.1448 sec/batch
# Epoch: 3/20...  Training Step: 494...  Training loss: 1.9287...  9.7190 sec/batch
# Epoch: 3/20...  Training Step: 495...  Training loss: 1.9222...  10.3810 sec/batch
# Epoch: 3/20...  Training Step: 496...  Training loss: 1.9058...  11.2545 sec/batch
# Epoch: 3/20...  Training Step: 497...  Training loss: 1.9507...  10.4570 sec/batch
# Epoch: 3/20...  Training Step: 498...  Training loss: 1.9440...  9.5659 sec/batch
# Epoch: 3/20...  Training Step: 499...  Training loss: 1.9251...  10.5381 sec/batch
# Epoch: 3/20...  Training Step: 500...  Training loss: 1.9378...  11.3266 sec/batch
# Epoch: 3/20...  Training Step: 501...  Training loss: 1.9222...  11.3179 sec/batch
# Epoch: 3/20...  Training Step: 502...  Training loss: 1.9493...  10.4672 sec/batch
# Epoch: 3/20...  Training Step: 503...  Training loss: 1.9322...  9.9517 sec/batch
# Epoch: 3/20...  Training Step: 504...  Training loss: 1.9511...  11.0207 sec/batch
# Epoch: 3/20...  Training Step: 505...  Training loss: 1.9535...  11.0209 sec/batch
# Epoch: 3/20...  Training Step: 506...  Training loss: 1.9390...  11.4161 sec/batch
# Epoch: 3/20...  Training Step: 507...  Training loss: 1.9348...  11.7664 sec/batch
# Epoch: 3/20...  Training Step: 508...  Training loss: 1.9291...  10.5136 sec/batch
# Epoch: 3/20...  Training Step: 509...  Training loss: 1.9230...  10.2174 sec/batch
# Epoch: 3/20...  Training Step: 510...  Training loss: 1.9254...  8.9585 sec/batch
# Epoch: 3/20...  Training Step: 511...  Training loss: 1.9075...  9.5052 sec/batch
# Epoch: 3/20...  Training Step: 512...  Training loss: 1.8929...  9.8886 sec/batch
# Epoch: 3/20...  Training Step: 513...  Training loss: 1.9251...  12.4448 sec/batch
# Epoch: 3/20...  Training Step: 514...  Training loss: 1.9128...  10.1314 sec/batch
# Epoch: 3/20...  Training Step: 515...  Training loss: 1.9308...  11.0414 sec/batch
# Epoch: 3/20...  Training Step: 516...  Training loss: 1.9251...  11.2680 sec/batch
# Epoch: 3/20...  Training Step: 517...  Training loss: 1.9407...  12.0290 sec/batch
# Epoch: 3/20...  Training Step: 518...  Training loss: 1.9072...  11.7318 sec/batch
# Epoch: 3/20...  Training Step: 519...  Training loss: 1.8954...  11.4091 sec/batch
# Epoch: 3/20...  Training Step: 520...  Training loss: 1.9484...  10.1903 sec/batch
# Epoch: 3/20...  Training Step: 521...  Training loss: 1.9142...  10.5986 sec/batch
# Epoch: 3/20...  Training Step: 522...  Training loss: 1.8842...  10.3674 sec/batch
# Epoch: 3/20...  Training Step: 523...  Training loss: 1.9360...  10.9418 sec/batch
# Epoch: 3/20...  Training Step: 524...  Training loss: 1.9328...  11.6963 sec/batch
# Epoch: 3/20...  Training Step: 525...  Training loss: 1.9192...  11.6633 sec/batch
# Epoch: 3/20...  Training Step: 526...  Training loss: 1.9161...  11.8339 sec/batch
# Epoch: 3/20...  Training Step: 527...  Training loss: 1.8882...  10.9373 sec/batch
# Epoch: 3/20...  Training Step: 528...  Training loss: 1.8981...  11.1740 sec/batch
# Epoch: 3/20...  Training Step: 529...  Training loss: 1.9379...  9.4273 sec/batch
# Epoch: 3/20...  Training Step: 530...  Training loss: 1.9290...  9.3768 sec/batch
# Epoch: 3/20...  Training Step: 531...  Training loss: 1.9164...  11.9110 sec/batch
# Epoch: 3/20...  Training Step: 532...  Training loss: 1.9229...  12.1876 sec/batch
# Epoch: 3/20...  Training Step: 533...  Training loss: 1.9233...  10.2530 sec/batch
# Epoch: 3/20...  Training Step: 534...  Training loss: 1.9150...  10.0342 sec/batch
# Epoch: 3/20...  Training Step: 535...  Training loss: 1.9501...  10.1748 sec/batch
# Epoch: 3/20...  Training Step: 536...  Training loss: 1.8994...  9.4869 sec/batch
# Epoch: 3/20...  Training Step: 537...  Training loss: 1.9409...  10.3864 sec/batch
# Epoch: 3/20...  Training Step: 538...  Training loss: 1.9100...  10.3714 sec/batch
# Epoch: 3/20...  Training Step: 539...  Training loss: 1.9020...  10.2436 sec/batch
# Epoch: 3/20...  Training Step: 540...  Training loss: 1.9122...  10.6628 sec/batch
# Epoch: 3/20...  Training Step: 541...  Training loss: 1.8912...  11.6243 sec/batch
# Epoch: 3/20...  Training Step: 542...  Training loss: 1.9291...  12.7855 sec/batch
# Epoch: 3/20...  Training Step: 543...  Training loss: 1.9211...  12.8290 sec/batch
# Epoch: 3/20...  Training Step: 544...  Training loss: 1.9252...  11.4912 sec/batch
# Epoch: 3/20...  Training Step: 545...  Training loss: 1.9064...  11.2940 sec/batch
# Epoch: 3/20...  Training Step: 546...  Training loss: 1.8955...  11.4041 sec/batch
# Epoch: 3/20...  Training Step: 547...  Training loss: 1.8914...  11.6433 sec/batch
# Epoch: 3/20...  Training Step: 548...  Training loss: 1.9317...  13.7447 sec/batch
# Epoch: 3/20...  Training Step: 549...  Training loss: 1.9101...  10.9349 sec/batch
# Epoch: 3/20...  Training Step: 550...  Training loss: 1.9086...  10.5825 sec/batch
# Epoch: 3/20...  Training Step: 551...  Training loss: 1.9061...  11.3954 sec/batch
# Epoch: 3/20...  Training Step: 552...  Training loss: 1.8888...  10.5652 sec/batch
# Epoch: 3/20...  Training Step: 553...  Training loss: 1.9074...  11.6239 sec/batch
# Epoch: 3/20...  Training Step: 554...  Training loss: 1.8905...  10.4894 sec/batch
# Epoch: 3/20...  Training Step: 555...  Training loss: 1.8710...  10.5065 sec/batch
# Epoch: 3/20...  Training Step: 556...  Training loss: 1.9261...  10.6086 sec/batch
# Epoch: 3/20...  Training Step: 557...  Training loss: 1.9233...  11.9436 sec/batch
# Epoch: 3/20...  Training Step: 558...  Training loss: 1.8983...  11.1194 sec/batch
# Epoch: 3/20...  Training Step: 559...  Training loss: 1.9143...  10.8577 sec/batch
# Epoch: 3/20...  Training Step: 560...  Training loss: 1.8950...  11.5177 sec/batch
# Epoch: 3/20...  Training Step: 561...  Training loss: 1.8906...  11.2525 sec/batch
# Epoch: 3/20...  Training Step: 562...  Training loss: 1.8877...  10.8627 sec/batch
# Epoch: 3/20...  Training Step: 563...  Training loss: 1.9087...  12.0946 sec/batch
# Epoch: 3/20...  Training Step: 564...  Training loss: 1.9428...  11.3055 sec/batch
# Epoch: 3/20...  Training Step: 565...  Training loss: 1.8811...  11.1920 sec/batch
# Epoch: 3/20...  Training Step: 566...  Training loss: 1.8884...  12.0914 sec/batch
# Epoch: 3/20...  Training Step: 567...  Training loss: 1.8689...  12.0438 sec/batch
# Epoch: 3/20...  Training Step: 568...  Training loss: 1.8764...  11.7243 sec/batch
# Epoch: 3/20...  Training Step: 569...  Training loss: 1.9071...  11.8226 sec/batch
# Epoch: 3/20...  Training Step: 570...  Training loss: 1.8972...  11.9810 sec/batch
# Epoch: 3/20...  Training Step: 571...  Training loss: 1.8862...  11.7112 sec/batch
# Epoch: 3/20...  Training Step: 572...  Training loss: 1.8774...  13.2004 sec/batch
# Epoch: 3/20...  Training Step: 573...  Training loss: 1.8676...  12.1707 sec/batch
# Epoch: 3/20...  Training Step: 574...  Training loss: 1.8889...  12.0462 sec/batch
# Epoch: 3/20...  Training Step: 575...  Training loss: 1.8557...  11.9071 sec/batch
# Epoch: 3/20...  Training Step: 576...  Training loss: 1.8512...  11.3736 sec/batch
# Epoch: 3/20...  Training Step: 577...  Training loss: 1.8555...  10.9783 sec/batch
# Epoch: 3/20...  Training Step: 578...  Training loss: 1.8807...  9.9128 sec/batch
# Epoch: 3/20...  Training Step: 579...  Training loss: 1.8838...  11.5032 sec/batch
# Epoch: 3/20...  Training Step: 580...  Training loss: 1.9056...  10.6756 sec/batch
# Epoch: 3/20...  Training Step: 581...  Training loss: 1.8938...  9.4803 sec/batch
# Epoch: 3/20...  Training Step: 582...  Training loss: 1.8601...  10.7057 sec/batch
# Epoch: 3/20...  Training Step: 583...  Training loss: 1.8743...  11.1725 sec/batch
# Epoch: 3/20...  Training Step: 584...  Training loss: 1.8517...  11.7812 sec/batch
# Epoch: 3/20...  Training Step: 585...  Training loss: 1.8641...  10.6101 sec/batch
# Epoch: 3/20...  Training Step: 586...  Training loss: 1.8811...  11.5557 sec/batch
# Epoch: 3/20...  Training Step: 587...  Training loss: 1.8816...  11.7399 sec/batch
# Epoch: 3/20...  Training Step: 588...  Training loss: 1.8318...  11.2185 sec/batch
# Epoch: 3/20...  Training Step: 589...  Training loss: 1.8739...  10.6326 sec/batch
# Epoch: 3/20...  Training Step: 590...  Training loss: 1.8455...  11.4176 sec/batch
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-ad76a1595262> in <module>()
#      28                                                  model.final_state,
#      29                                                  model.optimizer],
# ---> 30                                                  feed_dict=feed)
#      31
#      32             end = time.time()
#
# E:\Anaconda\Anaconda3\envs\rnn\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     787     try:
#     788       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 789                          run_metadata_ptr)
#     790       if run_metadata:
#     791         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# E:\Anaconda\Anaconda3\envs\rnn\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     995     if final_fetches or final_targets:
#     996       results = self._do_run(handle, final_targets, final_fetches,
# --> 997                              feed_dict_string, options, run_metadata)
#     998     else:
#     999       results = []
#
# E:\Anaconda\Anaconda3\envs\rnn\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1130     if handle is None:
#    1131       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1132                            target_list, options, run_metadata)
#    1133     else:
#    1134       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# E:\Anaconda\Anaconda3\envs\rnn\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1137   def _do_call(self, fn, *args):
#    1138     try:
# -> 1139       return fn(*args)
#    1140     except errors.OpError as e:
#    1141       message = compat.as_text(e.message)
#
# E:\Anaconda\Anaconda3\envs\rnn\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1119         return tf_session.TF_Run(session, options,
#    1120                                  feed_dict, fetch_list, target_list,
# -> 1121                                  status, run_metadata)
#    1122
#    1123     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# #### Saved checkpoints
#
# Read up on saving and loading checkpoints here: https://www.tensorflow.org/programmers_guide/variables

# %%
tf.train.get_checkpoint_state('checkpoints')

# %% [markdown]
# ## Sampling
#
# Now that the network is trained, we'll can use it to generate new text. The idea is that we pass in a character, then the network will predict the next character. We can use the new one, to predict the next one. And we keep doing this to generate all new text. I also included some functionality to prime the network with some text by passing in a string and building up a state from that.
#
# The network gives us predictions for each character. To reduce noise and make things a little less random, I'm going to only choose a new character from the top N most likely characters.

# %%
def pick_top_n(preds, vocab_size, top_n=5):
    p = np.squeeze(preds)
    p[np.argsort(p)[:-top_n]] = 0
    p = p / np.sum(p)
    c = np.random.choice(vocab_size, 1, p=p)[0]
    return c

# %%
def sample(checkpoint, n_samples, lstm_size, vocab_size, prime="The "):
    samples = [c for c in prime]
    model = CharRNN(len(vocab), lstm_size=lstm_size, sampling=True)
    saver = tf.train.Saver()
    with tf.Session() as sess:
        saver.restore(sess, checkpoint)
        new_state = sess.run(model.initial_state)
        for c in prime:
            x = np.zeros((1, 1))
            x[0,0] = vocab_to_int[c]
            feed = {model.inputs: x,
                    model.keep_prob: 1.,
                    model.initial_state: new_state}
            preds, new_state = sess.run([model.prediction, model.final_state], 
                                         feed_dict=feed)

        c = pick_top_n(preds, len(vocab))
        samples.append(int_to_vocab[c])

        for i in range(n_samples):
            x[0,0] = c
            feed = {model.inputs: x,
                    model.keep_prob: 1.,
                    model.initial_state: new_state}
            preds, new_state = sess.run([model.prediction, model.final_state], 
                                         feed_dict=feed)

            c = pick_top_n(preds, len(vocab))
            samples.append(int_to_vocab[c])
        
    return ''.join(samples)

# %% [markdown]
# Here, pass in the path to a checkpoint and sample from the network.

# %%
tf.train.latest_checkpoint('checkpoints')
# Out:
# 'checkpoints/i3960_l512.ckpt'

# %%
checkpoint = tf.train.latest_checkpoint('checkpoints')
samp = sample(checkpoint, 2000, lstm_size, len(vocab), prime="Far")
print(samp)
# Out:
# Farens. The man and this presence there was a long whell against the
# serfice. And she would have seen a dest of sorry of any arrangements,
# true. But the side house was in the money about the chief same, and
# that he had to say to all his face, with some significance for his wife
# that he had come and done to the penslition of a little and sounds of
# the society, and always was in her and horses, and that that they
# could not be a chalacteristic on her so second become in her soul that it
# was all sincerity, and her clothest having been talking to horror of
# a presine that was something was all his mother had no station.
#
# The conversation had suddenly had not been anything.
#
# Sometying her health she came over the services, had sat down again, and
# at the conversation was not in the strange shreed to the door, and with
# his sight of the party, the sick man thinking the secret of the mother
# when they had brought a humored friends, and the prayers that he could not
# let him any more and marking this subject, and they. The most of the
# steps about indeed and triude of accordance of the position that was
# steping himself. They went to those on its ordered and could only to
# chart how when they all and the more angry and the sight about it. The
# peasants would his chillish accounts and at the partious feeling of
# particularly ares, and so thore was some shorting or them. And he so
# see the place, who was seeing that something coughed hands, as though
# he was at the same, was not that she was insulted. Anna had been at
# the prince tell out his hat this article and to begin to say.
#
# "Yive were a selvated the members who have taken the station in which the
# committee? And is to darling a minutate of the carriage of marnated. I have
# took to myself in the steps and a single morn and happy.
#
# "If that's into a single morning, this seems thanks to her and thinks
# in the past and married that." The side had been carrying all the
# portrait of his words. These wires he was sitting at the past of the
# room, t

# %%
checkpoint = 'checkpoints/i200_l512.ckpt'
samp = sample(checkpoint, 1000, lstm_size, len(vocab), prime="Far")
print(samp)
# Out:
# Fard,. ""
# I"
# "The tat he winse he wos al alt ong the hor an thot hed the
# the sin the sand we he sos and se th the an soris he as oth thes sosed to he the he ad ond on har soron sha sas sitis he
# sentes the he wis as arton thir ans on ond wome to whe the sos thes sosit to the sos at hos ho she sis the she him an tot thes th an setit and wo he angeras,. Tho hor ho wot thime
# ne tot ha to we we he won thar al thir send tougtint ting and wh wamed, the the her what hot wit he wat ta hor,
# thing th whe tousederede sad sithe the the he se the han shes oress ho tot on here an on ot to he the hhressasesid thise where ans andentor tat the
# t the won he ans te hite wost hin sos torinnd
# tare wes to se her
# inntor ond tot ont ate
# silt wens
# thithe serede ho he the soros, sers on asis and af on he tare sin hos tot this won oth the he tins, and ang tee ar the ant oud thot woth shat ha lan and sithe to she sos thoth sar te sesilt ther singetin to he te artor to ho he
# wans he ans her han ase and.
# I hind wasd we

# %%
checkpoint = 'checkpoints/i600_l512.ckpt'
samp = sample(checkpoint, 1000, lstm_size, len(vocab), prime="Far")
print(samp)
# Out:
# Farnt out a seenen a doons the werly a prostines, bet of to as sone him, al her his and and she had booke word and wert on her had and said to hoult, sto stat to she whon he wond to
# denting andond to stat had he he seed a sele to the corsions.
#
# "The more when she shead, thourg that so he had and to the sort, sunding him his and and sace and where her
# headed he said
# the haress and than sheard her, her has thing his stalith his tongenter," she said
# he dasted the monting the sond of
# their that allong her ald
# have a tare him that to the somesily wourd to dive in and som her and whene the sead, and withon te said whine and had sail he having had
# same to sime her has
# antanter that
# she she distlidion of her heally.
#
# "When, an the pinter on atone with
# the pasting, and sooked hus a sant of her his her ander was having to the panting to shingher at a shiss to thow to and walk nover as to the portanion," said Stepan'Akknavitcch with which all she coundsess in this his,
# boring the panitiou, and
# atonge

# %%
checkpoint = 'checkpoints/i1200_l512.ckpt'
samp = sample(checkpoint, 1000, lstm_size, len(vocab), prime="Far")
print(samp)
# Out:
# Farcial the
# confiring to the mone of the correm and thinds. She
# she saw the
# streads of herself hand only astended of the carres to her his some of the princess of which he came him of
# all that his white the dreasing of
# thisking the princess and with she was she had
# bettee a still and he was happined, with the pood on the mush to the peaters and seet it.
#
# "The possess a streatich, the may were notine at his mate a misted
# and the
# man of the mother at the same of the seem her
# felt. He had not here.
#
# "I conest only be alw you thinking that the partion
# of their said."
#
# "A much then you make all her
# somether. Hower their centing
# about
# this, and I won't give it in
# himself.
# I had not come at any see it will that there she chile no one that him.
#
# "The distiction with you all.... It was
# a mone of the mind were starding to the simple to a mone. It to be to ser in the place," said Vronsky.
# "And a plais in
# his face, has alled in the consess on at they to gan in the sint
# at as that
# he would not be and t
